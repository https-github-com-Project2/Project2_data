# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
world_bank_df = pd.read_csv("Resources/world_bank.csv")

# %%
world_bank_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 1  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 2  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 3  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 4  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2010          2011  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  19741.149800  19960.521210
# 1   NaN   NaN   NaN   NaN   NaN  ...    477.307009    517.448448
# 2   NaN   NaN   NaN   NaN   NaN  ...   1108.338717   1494.240377
# ...

# %%
new_bank_data_df = world_bank_df[['Country Code', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',]].copy()
new_bank_data_df.head()
# Out:
#   Country Code          2010          2011          2012          2013  \
# 0          ABW  19741.149800  19960.521210  21038.151120  20841.489470
# 1          AFG    477.307009    517.448448    554.779216    550.956701
# 2          AGO   1108.338717   1494.240377   1789.733615   2113.866121
# 3          ALB   3530.690656   3853.165353   3644.843103   3937.277061
# 4          AND           NaN           NaN           NaN           NaN
#
#            2014          2015          2016          2017
# 0  21891.503900  21961.098810  21368.804890  21385.451660
# 1    529.876402    502.276410    465.841583    466.079081
# 2   2498.701951   2341.460543   1949.114680   2148.272969
# 3   4038.014865   3560.787907   3776.111694   4105.150515
# 4           NaN           NaN           NaN           NaN

# %%
new_bank_data_df.to_csv("Resources/world_b.csv", index=False, header=True)

# %%
new_bank_data_df.count()
# Out:
# Country Code    264
# 2010            219
# 2011            221
# 2012            219
# 2013            220
# 2014            220
# 2015            219
# 2016            218
# 2017            217
# dtype: int64

# %%
cl_wb_df = new_bank_data_df.dropna(how='any')

# %%
cl_wb_df.count()
# Out:
# Country Code    214
# 2010            214
# 2011            214
# 2012            214
# 2013            214
# 2014            214
# 2015            214
# 2016            214
# 2017            214
# dtype: int64

# %%
cl_wb_df = pd.read_csv("Resources/world_b.csv")

# %%
kickstarter_df.head()
# Out:
#            ID                                               name  \
# 0    69489148                       Student Auditions Music 2015
# 1  1014746686     Salt of the Earth: A Dead Sea Movie (Canceled)
# 2  1245461087  1st Super-Size Painting - Social Network Owned...
# 3  1384087152                                "ICHOR"  (Canceled)
# 4  1480763647  Support Solo Theater! Help "Ungrateful Daughte...
#
#        category main_category currency    deadline     goal       launched  \
# 0    Publishing    Publishing      CHF  10/31/2015   1900.0  1/1/1970 1:00
# 1  Film & Video  Film & Video      USD   9/15/2010   5000.0  1/1/1970 1:00
# 2           Art           Art      USD   8/14/2010  15000.0  1/1/1970 1:00
# 3  Film & Video  Film & Video      USD   5/21/2010    700.0  1/1/1970 1:00
# 4       Theater       Theater      USD    6/1/2010   4000.0  1/1/1970 1:00
#
#    pledged      state  backers country  usd pledged  usd_pledged_real  \
# ...

# %%
new_ks_data_df = kickstarter_df[['ID', 'category', 'main_category', 'country', 'launched', 'goal', 'state', 'usd_goal_real',]].copy()
new_ks_data_df.count()
# Out:
# ID               378661
# category         378661
# main_category    378661
# country          378661
# launched         378661
# goal             378661
# state            378661
# usd_goal_real    378661
# dtype: int64

# %%
cl_ks_df = new_ks_data_df.dropna(how='any')

# %%
cl_ks_df.count()
# Out:
# ID               378661
# category         378661
# main_category    378661
# country          378661
# launched         378661
# goal             378661
# state            378661
# usd_goal_real    378661
# dtype: int64

# %%
cl_ks_df.head()
# Out:
#            ID      category main_category country       launched     goal  \
# 0    69489148    Publishing    Publishing      CH  1/1/1970 1:00   1900.0
# 1  1014746686  Film & Video  Film & Video      US  1/1/1970 1:00   5000.0
# 2  1245461087           Art           Art      US  1/1/1970 1:00  15000.0
# 3  1384087152  Film & Video  Film & Video      US  1/1/1970 1:00    700.0
# 4  1480763647       Theater       Theater      US  1/1/1970 1:00   4000.0
#
#        state  usd_goal_real
# 0  suspended        1905.97
# 1   canceled        5000.00
# 2   canceled       15000.00
# 3   canceled         700.00
# 4   canceled        4000.00

# %%
cl_kick_df = cl_ks_df[(cl_ks_df['state'] == "successful") | (cl_ks_df['state'] == "failed")]

# %%
cl_kick_df.head()
# Out:
#             ID      category main_category country         launched     goal  \
# 7   1860890148       Fashion       Fashion      US  4/21/2009 21:02   1000.0
# 8    709707365        Shorts  Film & Video      US   4/23/2009 0:07  80000.0
# 9   1703704063  Illustration           Art      US  4/24/2009 21:52     20.0
# 10      727286      Software    Technology      US  4/25/2009 17:36     99.0
# 11  1622952265       Fashion       Fashion      US  4/27/2009 14:10   1900.0
#
#          state  usd_goal_real
# 7       failed         1000.0
# 8       failed        80000.0
# 9   successful           20.0
# 10  successful           99.0
# 11      failed         1900.0

# %%
cl_kick_df.to_csv("Resources/kickstarter.csv", index=False, header=True)
